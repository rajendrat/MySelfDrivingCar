# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import csv
import cv2
import os
import numpy as np
import time
import matplotlib.pyplot as plt

def load_and_scale_images(folder):
    """Load and scale the new images to be 32x32x3"""
    image_names = os.listdir(folder)
    #image_names.remove('.DS_Store')
    bgr_images = [cv2.imread(folder + "/" + name) for name in image_names]
    
    rgb_images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in bgr_images]
    resized_images = [cv2.resize(img, (32, 32)) for img in rgb_images]
    
    i = 1;
    for rimg in resized_images:
        fname = 'resizedImages0' + str(i) + '.png'
        cv2.imwrite(fname,rimg)
        i += 1
    return np.array(resized_images)

def load_images(folder):
    image_names = os.listdir(folder)
    #image_names.remove('.DS_Store')
    bgr_images = [cv2.imread(folder + "/" + name) for name in image_names]
    
    rgb_images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in bgr_images]

    return np.array(rgb_images)

# %%
images = load_and_scale_images("NewImages")
newimages = load_images("NewImages32x32")

# %%
def display_new_images(images):
    plt.figure(figsize=(15, 15))
    i = 1
    for image in images:
        plt.subplot(8, 8, i)
        plt.axis('off')
        plt.title("Image {0}".format(i))
        plt.imshow(image)
        i += 1

    plt.show()
    return

# %%
display_new_images(images)

# %%
display_new_images(newimages)

# %%
import pickle
pickle.dump( images, open( "NewImages.p", "wb" ) )
